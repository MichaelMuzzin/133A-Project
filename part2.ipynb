# %%
import pandas as pd
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import os
from setting import DROP_FEATURES
plt.style.use('ggplot')

# %%
df = pd.read_csv('survey_results_public.csv' , index_col='ResponseId')
pd.set_option('display.max_columns', 35)
pd.set_option('display.max_rows', 100)
df = df.drop(DROP_FEATURES, axis=1)
country_grp = df.groupby(['Country'])
America = country_grp.get_group('United States of America').copy()
America = America.drop('Country', axis=1)
America

# employment = df['Employment'].value_counts()
# employment
# Out:
# /var/folders/_y/yj2br66n1s11j40c681dw54w0000gn/T/ipykernel_37920/276463001.py:6: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   America = country_grp.get_group('United States of America').copy()
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 7           I am not primarily a developer, but I write co...
# 11          I used to be a developer by profession, but no...
# 13                             I am a developer by profession
# ...                                                       ...
# 65257                          I am a developer by profession
# 65262                          I am a developer by profession
# 65269                          I am a developer by profession
# 65270       I am not primarily a developer, but I write co...
# 65271                          I am a developer by profession
#
#                            Age  \
# ResponseId
# 1           Under 18 years old
# 6           Under 18 years old
# 7              35-44 years old
# 11             35-44 years old
# 13             35-44 years old
# ...                        ...
# 65257          35-44 years old
# 65262          18-24 years old
# 65269          25-34 years old
# 65270          45-54 years old
# 65271          45-54 years old
#
#                                                    Employment  \
# ResponseId
# 1                                         Employed, full-time
# 6                                          Student, full-time
# 7                                         Employed, full-time
# 11                                        Employed, full-time
# 13                                        Employed, full-time
# ...                                                       ...
# 65257                                     Employed, full-time
# 65262                                     Employed, full-time
# 65269       Employed, full-time;Independent contractor, fr...
# 65270                                     Employed, full-time
# 65271                                     Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 1                                         Remote
# 6                                            NaN
# 7                                         Remote
# 11                                        Remote
# 13          Hybrid (some remote, some in-person)
# ...                                          ...
# 65257                                     Remote
# 65262       Hybrid (some remote, some in-person)
# 65269                                     Remote
# 65270                                     Remote
# 65271                                     Remote
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 6                                                         NaN
# 7                                I don’t code outside of work
# 11                   Hobby;Contribute to open-source projects
# 13          Hobby;Contribute to open-source projects;Profe...
# ...                                                       ...
# 65257       Bootstrapping a business;Professional developm...
# 65262                                                   Hobby
# 65269       Bootstrapping a business;Professional developm...
# 65270       Professional development or self-paced learnin...
# 65271       Contribute to open-source projects;Bootstrappi...
#
#                                                       EdLevel  \
# ResponseId
# 1                                   Primary/elementary school
# 6                                   Primary/elementary school
# 7              Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 11               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 65257         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65262       Some college/university study without earning ...
# 65269            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65270       Some college/university study without earning ...
# 65271         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1                                      Books / Physical media       NaN
# 6           School (i.e., University, College, etc);Online...        10
# 7           Other online resources (e.g., videos, blogs, f...         7
# 11          Books / Physical media;Other online resources ...        20
# 13          Books / Physical media;On the job training;Sch...        20
# ...                                                       ...       ...
# 65257       On the job training;Other online resources (e....        30
# 65262       Other online resources (e.g., videos, blogs, f...         4
# 65269       Books / Physical media;Other online resources ...         9
# 65270       Books / Physical media;Other online resources ...        28
# 65271       Books / Physical media;Colleague;On the job tr...        41
#
#            YearsCodePro                               DevType  \
# ResponseId
# 1                   NaN                                   NaN
# 6                   NaN                               Student
# 7                     7                   Academic researcher
# 11                  NaN                       Project manager
# 13                   12                   Developer, back-end
# ...                 ...                                   ...
# 65257                 7               Other (please specify):
# 65262                 2                 Developer, full-stack
# 65269                 5                 Developer, full-stack
# 65270                25  Senior Executive (C-Suite, VP, etc.)
# 65271                25           Research & Development role
#
#                              OrgSize  CompTotal  \
# ResponseId
# 1                                NaN        NaN
# 6                                NaN        NaN
# 7                                NaN        NaN
# 11                               NaN        NaN
# 13                               NaN        NaN
# ...                              ...        ...
# 65257               2 to 9 employees        NaN
# 65262             20 to 99 employees    40000.0
# 65269       10,000 or more employees   130000.0
# 65270           100 to 499 employees   250000.0
# 65271       1,000 to 4,999 employees   157000.0
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 6           Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 7                                                           R
# 11                                     JavaScript;Python;Ruby
# 13          Bash/Shell (all shells);C#;JavaScript;PowerShe...
# ...                                                       ...
# 65257                           C;C++;Python;Swift;TypeScript
# 65262               HTML/CSS;JavaScript;Python;SQL;TypeScript
# 65269                              C#;HTML/CSS;JavaScript;SQL
# 65270                                                     NaN
# 65271                                               C++;Swift
#
#                              DatabaseHaveWorkedWith  \
# ResponseId
# 1                                               NaN
# 6                                   Cloud Firestore
# 7                                               NaN
# 11          Elasticsearch;MongoDB;PostgreSQL;SQLite
# 13                                            MySQL
# ...                                             ...
# 65257         InfluxDB;MariaDB;MongoDB;MySQL;SQLite
# 65262                                    PostgreSQL
# 65269               Microsoft SQL Server;PostgreSQL
# 65270                                           NaN
# 65271                                           NaN
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 6                                                  Cloudflare
# 7                                                         NaN
# 11                     Amazon Web Services (AWS);Google Cloud
# 13          Amazon Web Services (AWS);Google Cloud;Hetzner...
# ...                                                       ...
# 65257                               Amazon Web Services (AWS)
# 65262                    Amazon Web Services (AWS);Cloudflare
# 65269                            Google Cloud;Microsoft Azure
# 65270                                                     NaN
# 65271                                                     NaN
#
#                                  WebframeHaveWorkedWith  \
# ResponseId
# 1                                                   NaN
# 6                                               Node.js
# 7                                                   NaN
# 11                          Node.js;React;Ruby on Rails
# 13                                                  NaN
# ...                                                 ...
# 65257                             Angular;Express;Flask
# 65262                          Next.js;Svelte;WordPress
# 65269       AngularJS;Astro;jQuery;Node.js;React;Vue.js
# 65270                                               NaN
# 65271                                             React
#
#            EmbeddedHaveWorkedWith                          OpSysPersonal use  \
# ResponseId
# 1                             NaN                                        NaN
# 6                     Rasberry Pi                           iOS;MacOS;Ubuntu
# 7                             NaN                                      MacOS
# 11                            NaN  Windows;Windows Subsystem for Linux (WSL)
# 13                            NaN  Windows;Windows Subsystem for Linux (WSL)
# ...                           ...                                        ...
# 65257                LLVM's Clang                               MacOS;Ubuntu
# 65262                 Rasberry Pi                                    Windows
# 65269                 Rasberry Pi                Fedora;MacOS;Ubuntu;Windows
# 65270                         NaN                                        NaN
# 65271                         NaN      Android;iOS;Other Linux-based;Windows
#
#                                OpSysProfessional use  \
# ResponseId
# 1                                                NaN
# 6                                                NaN
# 7                                              MacOS
# 11                                           Windows
# 13                 Windows Subsystem for Linux (WSL)
# ...                                              ...
# 65257                                   MacOS;Ubuntu
# 65262       Ubuntu;Windows Subsystem for Linux (WSL)
# 65269                                          MacOS
# 65270                                            NaN
# 65271                                            NaN
#
#                                     AISearchDevHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 6                         ChatGPT;GitHub Copilot;OpenAI Codex
# 7                                                         NaN
# 11          ChatGPT;GitHub Copilot;Google Gemini;Meta AI;V...
# 13                                                        NaN
# ...                                                       ...
# 65257       ChatGPT;GitHub Copilot;Google Gemini;Meta AI;P...
# 65262                                  ChatGPT;GitHub Copilot
# 65269                           ChatGPT;Google Gemini;Meta AI
# 65270                                                     NaN
# 65271                                                     NaN
#
#                            AISelect  \
# ResponseId
# 1                               Yes
# 6                               Yes
# 7           No, and I don't plan to
# 11                              Yes
# 13          No, and I don't plan to
# ...                             ...
# 65257                           Yes
# 65262                           Yes
# 65269                           Yes
# 65270        No, but I plan to soon
# 65271       No, and I don't plan to
#
#                                                         AIBen  \
# ResponseId
# 1                                       Increase productivity
# 6           Increase productivity;Greater efficiency;Impro...
# 7                                                         NaN
# 11          Increase productivity;Speed up learning;Improv...
# 13                                                        NaN
# ...                                                       ...
# 65257                 Increase productivity;Speed up learning
# 65262                Increase productivity;Greater efficiency
# 65269       Increase productivity;Greater efficiency;Speed...
# 65270                                                     NaN
# 65271                                                     NaN
#
#                         AIAcc  \
# ResponseId
# 1                         NaN
# 6              Somewhat trust
# 7                         NaN
# 11          Somewhat distrust
# 13                        NaN
# ...                       ...
# 65257       Somewhat distrust
# 65262       Somewhat distrust
# 65269         Highly distrust
# 65270                     NaN
# 65271                     NaN
#
#                                         AIToolCurrently Using AIThreat  \
# ResponseId
# 1                                                         NaN      NaN
# 6                     Writing code;Debugging and getting help       No
# 7                                                         NaN      NaN
# 11          Learning about a codebase;Writing code;Documen...       No
# 13                                                        NaN      NaN
# ...                                                       ...      ...
# 65257                         Writing code;Search for answers       No
# 65262                                            Writing code       No
# 65269       Learning about a codebase;Documenting code;Deb...       No
# 65270                                                     NaN       No
# 65271                                                     NaN      NaN
#
#                                                      AIEthics  \
# ResponseId
# 1                                                         NaN
# 6           Circulating misinformation or disinformation;M...
# 7                                                         NaN
# 11          Circulating misinformation or disinformation;M...
# 13                                                        NaN
# ...                                                       ...
# 65257       Missing or incorrect attribution for sources o...
# 65262       Circulating misinformation or disinformation;M...
# 65269       Circulating misinformation or disinformation;B...
# 65270       Circulating misinformation or disinformation;M...
# 65271                                                     NaN
#
#                                                  AIChallenges  \
# ResponseId
# 1                                                         NaN
# 6                                                         NaN
# 7                                                         NaN
# 11          Don’t trust the output or answers;AI tools lac...
# 13                                                        NaN
# ...                                                       ...
# 65257                       Don’t trust the output or answers
# 65262       Don’t trust the output or answers;AI tools lac...
# 65269       Don’t trust the output or answers;AI tools lac...
# 65270       Don’t trust the output or answers;Lack of prop...
# 65271                                                     NaN
#
#                             ICorPM  WorkExp  \
# ResponseId
# 1                              NaN      NaN
# 6                              NaN      NaN
# 7                              NaN      NaN
# 11          Individual contributor     15.0
# 13          Individual contributor     12.0
# ...                            ...      ...
# 65257                          NaN      NaN
# 65262       Individual contributor      4.0
# 65269       Individual contributor      5.0
# 65270                          NaN      NaN
# 65271       Individual contributor     25.0
#
#                                                   Frustration  \
# ResponseId
# 1                                                         NaN
# 6                                                         NaN
# 7                                                         NaN
# 11          Amount of technical debt;Number of software to...
# 13          Amount of technical debt;Complexity of tech st...
# ...                                                       ...
# 65257                                                     NaN
# 65262                                                     NaN
# 65269                                           None of these
# 65270                                                     NaN
# 65271                                                     NaN
#
#                         Industry  JobSat
# ResponseId
# 1                            NaN     NaN
# 6                            NaN     NaN
# 7                            NaN     NaN
# 11                    Healthcare     8.0
# 13          Software Development     8.0
# ...                          ...     ...
# 65257                        NaN     NaN
# 65262                        NaN     NaN
# 65269                        NaN     NaN
# 65270                        NaN     NaN
# 65271                        NaN     NaN
#
# [11095 rows x 32 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.impute import SimpleImputer
from scipy.linalg import svd

# Load the dataset
file_path = "survey_results_public.csv"  # Update path if needed
df = pd.read_csv(file_path, index_col="ResponseId")

# Filter for United States data
country_grp = df.groupby("Country")
if "United States of America" in country_grp.groups:
    America = country_grp.get_group("United States of America").copy()
    America = America.drop(columns=["Country"])  # Drop redundant column
else:
    raise ValueError("United States data not found in dataset.")

# Select only numeric features
America_numeric = America.select_dtypes(include=["number"]).dropna(axis=1, how="all")

# Standardize the dataset
scaler = StandardScaler()
America_standardized = pd.DataFrame(scaler.fit_transform(America_numeric), columns=America_numeric.columns)

# Compute mean and standard deviation
feature_stats = pd.DataFrame({
    "Mean": America_standardized.mean(),
    "Standard Deviation": America_standardized.std()
})
print("\nFeature Statistics (Standardized Data):\n", feature_stats)

# Handle missing values by imputing the mean
imputer = SimpleImputer(strategy="mean")
America_standardized_imputed = pd.DataFrame(imputer.fit_transform(America_standardized),
                                            columns=America_standardized.columns)

# Perform K-Means Clustering with different k values
inertia = []
k_values = range(2, 11)  # Testing k from 2 to 10

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(America_standardized_imputed)
    inertia.append(kmeans.inertia_)

# Plot elbow method to determine optimal k
plt.figure(figsize=(8, 5))
plt.plot(k_values, inertia, marker="o", linestyle="-")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k in K-Means Clustering")
plt.show()

# Apply SVD
U, S, Vt = svd(America_standardized_imputed)
singular_values = pd.Series(S, name="Singular Values")

# Display top singular values
print("\nTop Singular Values:\n", singular_values.head(10))

# Compute correlation matrix
correlation_matrix = America_standardized_imputed.corr()

# Identify highly correlated features (absolute correlation > 0.8, excluding diagonal)
highly_correlated_features = correlation_matrix.where(
    np.triu(np.abs(correlation_matrix) > 0.8, k=1)
).stack().reset_index()
highly_correlated_features.columns = ["Feature 1", "Feature 2", "Correlation"]

print("\nHighly Correlated Features (|corr| > 0.8):\n", highly_correlated_features)

# Plot heatmap of correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", annot=False, linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5 from sklearn.preprocessing import StandardScaler
#       6 from sklearn.cluster import KMeans
#
# ModuleNotFoundError: No module named 'seaborn'
